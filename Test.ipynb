# %%
import torch

# %%
# Check if CUDA is available
cuda_available = torch.cuda.is_available()

if cuda_available:
    print("CUDA is available! You can use GPU acceleration.")
    print(f"Number of CUDA devices: {torch.cuda.device_count()}")
    print(f"Current CUDA device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. Running on CPU.")
# Out:
# CUDA is available! You can use GPU acceleration.
# Number of CUDA devices: 1
# Current CUDA device: 0
# Device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# Print PyTorch version
print(f"PyTorch version: {torch.__version__}")

# Print CUDA toolkit version
print(f"CUDA toolkit version: {torch.version.cuda}")

# Check if CUDA is available and print additional GPU info
if torch.cuda.is_available():
    print("CUDA is available!")
    print(f"Number of CUDA devices: {torch.cuda.device_count()}")
    print(f"Current CUDA device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available.")
# Out:
# PyTorch version: 2.4.0
# CUDA toolkit version: 11.8
# CUDA is available!
# Number of CUDA devices: 1
# Current CUDA device: 0
# Device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
import bayesflow as bf
# Out:
# WARNING:root:Some dependencies failed to load. BayesFlow modules may not work properly!
# WARNING:root:No module named 'tensorflow'
